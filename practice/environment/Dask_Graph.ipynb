# %% [markdown]
# # Dask graph computation
#
# Here we illustrate Dask graph for computation, the lazy mode, and parrallelism with distributed

# %%
import dask.array as da

# %% [markdown]
# ## Graph for chunk of operation

# %%
x = da.ones((4, 1), chunks=(2, 1))
x.visualize()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 2
#       1 x = da.ones((4, 1), chunks=(2, 1))
# ----> 2 x.visualize()
#
# File ~/miniconda3/envs/ds2-coiled/lib/python3.9/site-packages/dask/base.py:305, in DaskMethodsMixin.visualize(self, filename, format, optimize_graph, **kwargs)
#     261 def visualize(self, filename="mydask", format=None, optimize_graph=False, **kwargs):
#     262     """Render the computation of this object's task graph using graphviz.
#     263
#     264     Requires ``graphviz`` to be installed.
#    (...)
#     303     https://docs.dask.org/en/latest/optimize.html
#     304     """
# --> 305     return visualize(
#     306         self,
#     307         filename=filename,
#     308         format=format,
#     309         optimize_graph=optimize_graph,
#     310         **kwargs,
#     311     )
#
# File ~/miniconda3/envs/ds2-coiled/lib/python3.9/site-packages/dask/base.py:762, in visualize(filename, traverse, optimize_graph, maxval, engine, *args, **kwargs)
#     758 args, _ = unpack_collections(*args, traverse=traverse)
#     760 dsk = dict(collections_to_dsk(args, optimize_graph=optimize_graph))
# --> 762 return visualize_dsk(
#     763     dsk=dsk,
#     764     filename=filename,
#     765     traverse=traverse,
#     766     optimize_graph=optimize_graph,
#     767     maxval=maxval,
#     768     engine=engine,
#     769     **kwargs,
#     770 )
#
# File ~/miniconda3/envs/ds2-coiled/lib/python3.9/site-packages/dask/base.py:903, in visualize_dsk(dsk, filename, traverse, optimize_graph, maxval, o, engine, limit, **kwargs)
#     901     return cytoscape_graph(dsk, filename=filename, **kwargs)
#     902 elif engine is None:
# --> 903     raise RuntimeError(
#     904         "No visualization engine detected, please install graphviz or ipycytoscape"
#     905     )
#     906 else:
#     907     raise ValueError(f"Visualization engine {engine} not recognized")
#
# RuntimeError: No visualization engine detected, please install graphviz or ipycytoscape

# %%
y = 3 - da.ones((4, 1), chunks=(2,1))
y.visualize()

# %%
z = x.T * y
z.visualize()

# %%
x = da.triu(da.ones((3, 3), chunks=(1, 1)))
x.visualize()

# %%
print("Compare this print of x:")
print(x)
print("\nWith this one:")
print(x.compute())

# %%
x = da.triu(da.ones((4, 4), chunks=(2, 2)))
x.visualize()

# %% [markdown]
# ## Graph for lazy operations
#
# See here https://github.com/dask/dask-examples/blob/master/delayed.ipynb for more

# %%
# Init dummy functions
import time
import random

def inc(x):
    time.sleep(2)
    return x + 1

def dec(x):
    time.sleep(3)
    return x - 1
    
def add(x, y):
    time.sleep(1)
    return x + y

# %%
# %%time
# Bench these sequential list of function calls:
x = inc(1) # Return 1 + 1 = 2
y = dec(2) # Return 2 - 1 = 1
z = add(x, y) # Return 2 + 1 = 3
print("z =",z,"\n")

# %% [markdown]
# note that the x and y computations are performed sequentially, hence the 6sec of wall time

# %%
# Make these functions to be "lazy", so that they are executed only when needed:
import dask
inc = dask.delayed(inc)
dec = dask.delayed(dec)
add = dask.delayed(add)

# %%
# %%time
# Bench the same sequential list of function calls, but let Dask decide if they should be computed or not ("lazy" mode):
x = inc(1)
y = dec(2)
z = add(x, y)
print("z =",z,"\n")

# %% [markdown]
# see:
#
# - that `z` is now a `delayed` Dask object, the result (3) is not returned
# - how the wall time is much shorter, that's because the computation was not performed, only the graph was built

# %%
# This is the graph:
z.visualize(rankdir='LR')

# %%
# %%time
# In order to realy get the computation done, simple call "compute":
print("z =",z.compute(),"\n")

# %% [markdown]
# ## Lazy operations in parrallel with distributed
#
# *This won't work under Google Colab*

# %%
from dask.distributed import Client, progress
client = Client(threads_per_worker=4, n_workers=1)
client

# %%
# %%time
print("z =",z.compute(),"\n")

# %% [markdown]
# Here the point is to look at the Task Stream of the dashboard, which should look like the figure below:
#
# We see the parallel ``dec`` (magenta) and ``inc`` (green) calls lasting 3 and 2 secs respectively, followed by the ``add`` (blue) call lasting 1 sec. The total execution time in parallel is about 4 secs.
#
# ![](https://github.com/obidam/ds2-2025/raw/main/practice/environment/Dask_Graph.png)

# %%
client.close()
